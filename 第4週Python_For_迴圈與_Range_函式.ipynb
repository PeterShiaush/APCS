# %% [markdown]
# <a href="https://colab.research.google.com/github/PeterShiaush/APCS/blob/main/%E7%AC%AC4%E9%80%B1Python_For_%E8%BF%B4%E5%9C%88%E8%88%87_Range_%E5%87%BD%E5%BC%8F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 逐步執行以下:
#
# 1.   點擊上面的「**Open in Colab**」的連結
# 2.   再點擊上面  **複製到雲端硬碟**，成為**自己的colab 檔案**
# 3.   再**左上角** 修改檔名  : **第4週Python For 迴圈與 Range 函式.ipynb**
# 4.   右上角，輪圈(設定): 編輯器，**顯示行號**
#
# ### 記得 **顯示行號**
# ---

# %% [markdown]
# 這份為 **第四週：重複的力量 — for 迴圈** 設計的互動式筆記，是程式設計中最具威力的轉折點。本週重點在於讓學生理解如何讓電腦幫我們執行重複、枯燥的任務，並掌握 Python 最核心的 `range()` 函式。
#
# ---

# %% [markdown]
# # **第 4 週：複習的力量 — 變數
#
# ## **【讓電腦幫你記得事情的變數】 好處在哪裡???**

# %%
print(f"半徑10cm的圓，圓周長 {2*3.14*10:.1f} cm")
print(f"半徑10cm的圓，面積 {3.14*10*10:.1f} cm²")

# %% [markdown]
# 以上的**缺點**，不易了解，不易修改
#
# ----
#
# 請將以下程式碼，改為
#
# 半徑 = 100
#
# pi=3.1416

# %%
print(f"半徑10cm的圓，圓周長 {2*3.14*10:.1f} cm")
print(f"半徑10cm的圓，面積 {3.14*10*10:.1f} cm²")

# %% [markdown]
# ---
# 以下**清楚明瞭，修改容易**
#
# 改為
#
# 半徑 = 100
#
# pi=3.1416

# %%
radius = 10 # 修正為 100
PI = 3.14 # 修正為 3.1416
circumference = 2 * PI * radius
area = PI * (radius ** 2)
print(f"半徑10cm的圓，圓周長 {circumference:.1f} cm")
print(f"半徑10cm的圓，面積 {area:.1f} cm²")

# %% [markdown]
# # **第 4 週：重複的力量 — for 迴圈 (Week 4)**
#
# ## **【第一節：讓電腦幫你做重覆的事】 (50 分鐘)**
#
# [Houdini](https://blogger.googleusercontent.com/img/b/R29vZ2xl/AVvXsEhduXhtl2nTgnqeNa05wAIwMMJbpA-DpCFEgpxBUXAqYrshL1hglis_p_eGhxY8XzF13xdhRs5KNOtHiZ3faGnyX8MfMSGBfEJbUzpQLGbTvX2yEqpILqo2RMBybb9ziB2nIZLznPCW9ZZL/s1600/audience01.gif)
#
#
# https://public-files.gumroad.com/thkxavd4zkbw7arbvvboyrt0x7qa

# %%
print("迴圈第 0 次")
print("迴圈第 1 次")
print("迴圈第 2 次")
print("迴圈第 3 次")
print("迴圈第 4 次")
print("迴圈第 5 次")
print("迴圈第 6 次")
print("迴圈第 7 次")
print("迴圈第 8 次")
print("迴圈第 9 次")

# %% [markdown]
# ### **0. [想想區]：為何要使用 for 迴圈，我的生命不是如此浪費，我要玩電玩**
#
# 以上程式碼，沒有錯誤，但有何不方便?
# 如果，需要
#
# 迴圈第 0 次
#
# 迴圈第 1 次
#
# 迴圈第 2 次
#
# ........
#
# 迴圈第 999 次
#
# 迴圈第 **1000** 次
#
# ---

# %%
print("迴圈第 0 次")
print("迴圈第 1 次")
print("迴圈第 2 次")
print("迴圈第 3 次")
print("迴圈第 4 次")
print("迴圈第 5 次")
print("迴圈第 6 次")
print("迴圈第 7 次")
print("迴圈第 8 次")
print("迴圈第 9 次")
# 我複製，我改
print("迴圈第 0 次")
print("迴圈第 1 次")
print("迴圈第 2 次")
print("迴圈第 3 次")
print("迴圈第 4 次")
print("迴圈第 5 次")
print("迴圈第 6 次")
print("迴圈第 7 次")
print("迴圈第 8 次")
print("迴圈第 9 次")
# 我再複製，我再改
print("迴圈第 0 次")
print("迴圈第 1 次")
print("迴圈第 2 次")
print("迴圈第 3 次")
print("迴圈第 4 次")
print("迴圈第 5 次")
print("迴圈第 6 次")
print("迴圈第 7 次")
print("迴圈第 8 次")
print("迴圈第 9 次")

# %% [markdown]
# **??????????????????????????????**
#
# ----

# %% [markdown]
# ### **1. [教學區]：for 迴圈與 range() 函式**
#
# 當我們知道要重複執行「固定次數」時，就會使用 `for` 迴圈。而 `range()` 就像是一個數字產生器，產生一個範圍內的數字序列。
#
# **語法結構：**

# %%
for i in range(??):
    # 重複執行的程式碼 (記得縮排！) print()， 內含 "迴圈第", i, "次" 或 f"迴圈第 {i} 次"

# %% [markdown]
# * `range(5)`：產生 `0, 1, 2, 3, 4` (從 0 開始，**不包含** 5)。
# * `range(1, 6)`：產生 `1, 2, 3, 4, 5` (從 1 開始，到 6 之前停止)。
#
# ### **2. [任務區]：基礎迴圈練習（請填入 ???）**
#
# 請觀察輸出的需求，補全程式碼：

# %%
# 練習 1：印出「我以後會上課專心聽講」5 次
for i in range(???):
    print("我以後會上課專心聽講")

# 練習 2：印出 1 到 10 的數字
for i in range(1, ???):
    print(i)

# 練習 3：計算 1 加到 10 的總和 (累加器觀念)
sum_val = 0
for i in range(1, 11):
    sum_val = sum_val + ???  # 每次把目前的 i 加進盒子裡
print("總和為：", sum_val)

# %% [markdown]
# ---
#
# ## **【第二節：數列規律與 ZJ 實戰】 (50 分鐘)**
#
# ### **1. [教學區]：range() 的進階參數 — 步長 (Step)**
#
# `range(起始, 停止, 間隔)`
#
# * `range(2, 11, 2)`：產生 `2, 4, 6, 8, 10` (從 2 開始，每次跳 2 步)。
#
# ### **2. [任務區]：請補全數列與規律邏輯**

# %%
# 練習 1：印出 10 以內的奇數 (1, 3, 5, 7, 9)
for i in range(1, 11, ???):
    print(i)

# 練習 2：倒數計時！印出 5, 4, 3, 2, 1
# 提示：間隔可以是負數
for i in range(5, 0, ???):
    print(i)

# 練習 3：找出 1~100 之間，所有 7 的倍數
for i in range(1, 101):
    if i % 7 ??? 0:
        print(i, "是 7 的倍數")

# %% [markdown]
# ---
#
# ## **【ZeroJudge 實戰驗證：今日挑戰】**
#
# ### **題目 1：[c022: Odd Sum**](https://zerojudge.tw/ShowProblem?problemid=c022)
#
# * **目標**：計算範圍 [a, b] 之間所有「奇數」的總和。
# * **提示**：利用 `if i % 2 != 0` 來判斷奇數，並用變數累加。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
T = int(input()) # 讀取測試資料的組數

for i in range(?):
    a = int(input())
    b = int(input())
    total = 0

    for is_Odd in range(a, b + 0?):
        if is_Odd % 2 != 0:
            to?? = to?? + is_Odd

    print(f"Case {?+0?}: {to??}")

# %% [markdown]
# ---

# %% [markdown]
# ### **題目 2：[a005: Eva 的回家作業**](https://zerojudge.tw/ShowProblem?problemid=a005)
#
# * **目標**：判斷數列是「等差」還是「等比」，並推算第 5 個數。
# * **提示**：這題有「多筆測資」，需要先讀取筆數 `t`，再用 `for` 執行 `t` 次。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
t = int(input()) # 讀取有幾組數列
for i in range(???):
    a, b, c, d = map(int, input().split())
    if (b - a) == (c - b): # 如果是等差
        e = d + (b ??? a)
    else: # 否則就是等比 2/1 == 8/4
        e = d * (b ??? a)
    print(a, b, c, d, e)

# %% [markdown]
# ---
#
# ## **教師詳細導引過程 (100 分鐘流程)**
#
# ### **第一節 (50 分鐘)：迴圈的節奏感**
#
# 1. **情境引入 (10')**：問學生：「如果教務處要你印 1000 張獎狀，你會手寫 1000 次名字嗎？」引出電腦處理重複工作的強項。
# 2. **range() 實驗 (15')**：在 Colab 示範 `list(range(10))`，讓學生親自觀察「包含開頭、不含結尾」的特性。
# 3. **填空練習 (20')**：指導學生完成「第一節任務區」。**重點：** 強調 `sum_val = sum_val + i` 是程式設計中極其重要的「累加器」邏輯。
# 4. **視覺化除錯 (5')**：展示迴圈運行的圖解，讓學生理解 `i` 是如何隨時間改變的。
#
# ### **第二節 (50 分鐘)：規律發現與 ZJ 挑戰**
#
# 1. **間隔實驗 (15')**：引導學生玩 `range(0, 100, 13)`，看看會印出什麼，藉此理解「間隔」的妙用。
# 2. **ZJ 實戰 (25')**：
# * 引導學生完成 `c022`。這題是典型的「區間掃描」，對 APCS 實作第一題非常有幫助。
# * 對於自然組高二學生，`a005` 結合了數理邏輯與迴圈，是非常好的進階題。
#
#
# 3. **除錯提醒 (10')**：提醒學生，如果 `a=3, b=7`，`range(a, b)` 只會跑到 6。要跑到 7 必須寫成 `range(a, b + 1)`。
#
# ---
#
# **💡 教師小筆記：**
# 本週是學生最容易產生挫折感的地方，特別是「累加器」的概念（`x = x + 1` 在數學上不成立，但在程式中是賦值）。巡視時，請多確認學生的 `total` 變數是否有在迴圈開始前歸零 (`total = 0`)。下週我們將進入 `while` 迴圈！

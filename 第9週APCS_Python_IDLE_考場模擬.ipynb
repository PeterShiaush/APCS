# %% [markdown]
# <a href="https://colab.research.google.com/github/PeterShiaush/APCS/blob/main/%E7%AC%AC9%E9%80%B1APCS_Python_IDLE_%E8%80%83%E5%A0%B4%E6%A8%A1%E6%93%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 今天06/12，
#
# # **直接使用此 colab**
#
# 1. **不需要** Open in Colab
# 2. **不需要** 複製到雲端硬碟
# ---

# %% [markdown]
# # **複習** 第 8 週：進階開發與 APCS 實戰

# %% [markdown]
# ### **1. [教學區]：複習 Bug！**
#
# **VS Code** 專業開發者會使用 **偵錯器 (Debugger)** 來觀察程式執行的過程，此過程稱為 **debug** 。
#
# * **斷點 (Breakpoint)**：在行號左邊，點一下**紅點** 🔴，程式執行到這裡會「**暫停**」。

# %% [markdown]
# 1.0 [教學範例區]：VS Code 專案資料夾
#
# 1.   建立 資料夾: **debug_f**
# 2.   拖曳此資料夾，到 **vs code**
# 3.   信任此資料夾

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4.   滑鼠右鍵 New File: **hello.py**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **複製 hello.py 程式碼，如下**，在右側視窗貼上
#
# ```
# # vs code  使用 debug
# myHello = "Hello, Python"
# myAge = 16
# mySchool = "中山高中"
# print("111")
# print(myHello)  # 你第一個 在行號左邊，點一下紅點 🔴，程式執行到這裡會「暫停」
# print("222")
# print(myAge)  # 你2個 在行號左邊，點一下紅點 🔴，程式執行到這裡會「暫停」
# print("333")
# print(myHello)  # 你第3個 在行號左邊，點一下紅點 🔴，程式執行到這裡會「暫停」
# print("4444")
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 5.   **print(myHello)**，斷點 (Breakpoint)：在行號左邊，點一下紅點 🔴，程式執行到這裡會「暫停」。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *   **開始偵錯 (F5)**： 會彈出 "**Python Debugger**"、**"Python File**" 等選項供您點選。
#
#
#     * `F5`：開始偵錯。
#     * `F10`：跳到下一步 (Step Over)。
#     * **重複按 F10**

# %% [markdown]
# 注意輸出

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 這份為 **第九週：APCS 考前衝刺與 Python IDLE 環境實務** 設計的互動式教學講義，特別針對 APCS 官方指定的標準環境（Python 3.10.12）進行深度優化。
#
# 本週目標是讓學生從「開發者」模式切換回「考場應試」模式，熟悉在沒有高級 IDE 輔助的情況下，如何利用 **Python IDLE** 快速完成程式設計與除錯。
#
# ---

# %% [markdown]
# # **第 9 週：APCS 考場環境模擬與解題衝刺 (Week 9)**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **【第一節：考場環境體檢 — Python IDLE 3.10.12】 (50 分鐘)**
#
# ### **1. [教學區]：認識你的考場老夥伴**
#
# APCS 官方環境（如 Ubuntu Linux 或 Windows）均提供 **Python IDLE**。雖然它外表簡陋，但具備所有核心功能。
#
# * **搜尋**：
# ![image.png](data:image/png;base64,...)
#
# * **輸入**：**python**。或 **IDLE**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * **出現 Shell (互動視窗)**：看到紅色 `>>>`，此區域是顯示輸出結果，與報錯紅字的地方。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 環境設定
#
# * **Options**：
#   * **Fonts**：看到 `Consolas`，字大小 16。
#   * **Shell/Ed**：找到**顯示行號** Show line numbers in new windows 選項並勾選它。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# * **雙視窗切換**： `Ctrl + n` 新增檔案
#
#   * **Shell (互動視窗)**：看到 `>>>`，顯示輸出結果與報錯紅字的地方。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#   * **Editor (編輯視窗)**：`Ctrl + n` **新增檔案**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 2.1 [教學實戰區]：將無名 **untitled** 檔案，**儲存檔案** `Ctrl + s`

# %% [markdown]
# 1.   `Ctrl + s` **儲存檔案**
# 2.   文件，滑鼠右鍵，新增，建立的資料夾: **PythonIDLE**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1.   點擊新資料夾: PythonIDLE， 進入 資料夾: **PythonIDLE**
# 2.   **檔案名**，hello， 會自動**新增副檔案 .py**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **hello.py**，輸入
#
# ```
# # 你第一個 pythonIDLE的程式檔案
# myHello = "Hello, Python"
# print(myHello)
#
# ```

# %% [markdown]
# 4.   按 **F5**，執行，確定，儲存檔案

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 5.   檔案 **hello.py**，的執行結果，左邊的 **IDLE Shell**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **2. [任務區]：debugger環境操作**
#
# 1. **確認版本**：開啟 IDLE 後，第一行應顯示 Python **3.13**。
# 2. **開啟調試器（Debugger）**：點擊 **Debug**，開啟調試器（**Debugger**）

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 調試器（Debugger）:
#
# *   四個， 選 4個。
# *   注意左邊的五個按鈕 [Go]、[Step]、[Over]、[Out]、[Quit]。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 如何使用[Python 內建 IDLE 的除錯器(Debugger)](https://yunlinsong.blogspot.com/2019/10/python-idle-debugger.html)
#
#
# 1.   編輯視窗：Ctrl + n 新增檔案
# 2.   存檔：在 Editor 下，Ctrl + s， 存檔，檔名: **demo.pi**。
# 3.   複製貼上以下程式碼
# 4.   再按一次，Ctrl + s，
#
#
#
#
# ```
# # 此內容是 demo debug
#
# def main():
#     print("輸入長方形的長度，以及 輸入長方形的寬度")
#     print("計算 長方形的 面積與周長")
#     # 提示使用者輸入長方形的長度（此時輸入進來的是「字串」型態）
#     length = input("輸入長方形的長度 length:")
#
#     # 將字串型態的長度轉換成「整數（int）」，才能進行數學運算
#     length = int(length)
#
#     # 提示使用者輸入長方形的寬度
#     width = input("輸入長方形的寬度 width:")
#
#     # 將字串型態的寬度轉換成「整數（int）」
#     width = int(width)
#
#     # 計算面積：長度 乘以 寬度
#     area = length * width
#
#     # 計算周長：（長度 加上 寬度）再乘以 2
#     circumference = (length + width) * 2
#
#     # 在畫面上印出計算出來的面積結果
#     print("面積 Area:", area)
#
#     # 在畫面上印出計算出來的周長結果
#     print("周長 Circumference:", circumference)
#
# # 呼叫 main 函式，正式啟動並執行上面的所有程式碼
# main()
#
#
# ```

# %% [markdown]
# 在程式碼編輯視窗中，點擊，要設定中斷點的那一行程式碼，再按下滑鼠右鍵，選擇 [Set Breakpoint]
#
# **第10行 再按下滑鼠右鍵，選擇 [Set Breakpoint]**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 有設定中斷點的那一行顏色會不一樣，例如下圖就有三行有設定中斷點

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 在程式碼編輯視窗選單選擇[Run ==> Run Module] (或按下 F5 按鍵)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 此五個按鈕功能說明如下：
#
# *   [Go]：跳到下一個中斷點。
# *   [Step]：一行一行執行。若有函式呼叫，則會進入到函式實作的程式碼裡。
# *   [Over]：跳過(略過)函式呼叫。
# *   [Out]：跳出(離開)函式。
# *   [Quit]：結束除錯。

# %% [markdown]
# **F5**
#
# ![image.png](data:image/png;base64,...)
#
#
# 1.   [Go]：跳到下一個中斷點。
# 2.   [Go]：跳到下一個中斷點。
# 3.   [Go]：跳到下一個中斷點。

# %% [markdown]
# 觀察 輸入與輸出，注意 locals 變數的變化

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4. **直接判斷，錯誤類型**：錯在第???行，報錯訊息最後一行的 `???Error` 判斷錯誤類型。

# %% [markdown]
# ```
# # 有錯誤的程式碼
# # NameErrorE的程式檔案
# # 請修正
# myHello = "Hello, Python"
# print(myHello99)
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 5. **強制結束**：若程式進入無窮迴圈，按下 `Ctrl + ???` 可強行中斷執行。
#
# ---

# %% [markdown]
# ## **【第二節：APCS 第一題限時挑戰 — 邏輯整合】 (50 分鐘)**
#
# ### **1. [教學區]：APCS 讀取萬用框架**
#
# 在考場中，測資通常包含多行，且有時不告知數量。學會使用 `sys.stdin` 可以避免 `input()` 造成的 `EOFError`。
#
# ### **2. [任務區]：APCS 經典邏輯填空（以 [f605 購買力](https://zerojudge.tw/ShowProblem?problemid=f605)為例）

# %% [markdown]
# * **重點**：  `Ctrl + N` **新增檔案**，`Ctrl + s`，在資料夾: PythonIDLE，存成  **f605** ，副檔名py，會自動補上。Ctrl + s， 存檔，檔名建議依照題號命名。
#
# 複製貼上以下程式碼
# * **IDLE 練習要求**：請在 IDLE 的 Editor 中完成，並按 **F5** 測試。
# * **IDLE 測試資料**：請在 [f605 購買力](https://zerojudge.tw/ShowProblem?problemid=f605)網頁找測試範例。

# %%
# 練習：【APCS 實作一】模擬
import sys

def solve():
    # 讀取第一行 n (數量) 與 d (價差門檻)
    line = sys.stdin.readline()
    if not line: return
    n, d = map(int, line.split())

    buy_count = 0
    total_cost = 0

    for _ in range(n):
        # 讀取商品的 3 次價格
        prices = list(map(int, sys.stdin.readline().split()))

        # 找出最高價與最低價
        max_p = ???(prices)
        min_p = ???(prices)

        # 判斷是否購買
        if (max_p - min_p) ??? d:
            buy_count += 1
            # 計算平均值（3 次價格除以 3，並取整數）
            avg = sum(prices) // ???
            total_cost += avg

    print(buy_count, total_cost)

solve()

# %% [markdown]
# ---
#
# ## **【ZeroJudge 終極衝刺：考前手感練習】**
#
# ### 題目：[g275: 七言對聯](https://zerojudge.tw/ShowProblem?problemid=g275)
#
# * **邏輯重點**：這題是典型的「規則檢查」，需要同時判斷三個條件。
# * **邏輯核心**：程式是在檢查「違反規則」的狀況。**只要違反**了，就把錯誤代號（A、B、C）加入 ans 字串中。
# * **重點**：  `Ctrl + N` **新增檔案**，`Ctrl + s`，在資料夾: PythonIDLE，存成  **g275** ，副檔名py，會自動補上。
# * **IDLE 練習要求**：請在 IDLE 的 Editor 中完成，並按 **F5** 測試。
# * **IDLE 測試資料**：請在 [g275: 七言對聯**](https://zerojudge.tw/ShowProblem?problemid=g275)網頁找測試範例。

# %% [markdown]
# 這題的邏輯核心在於：程式是在檢查「違反規則」的狀況。只要違反了，就把錯誤代號（A、B、C）加入 ans 字串中。

# %%
# 補全對聯判斷邏輯
n = int(input())
for _ in range(n):
    a = list(map(int, input().split()))
    b = list(map(int, input().split()))
    ans = ""

    # 規則 A：二四六位置平仄需不同 (二 != 四, 二 == 六)
    if a[1] == a[3] or a[1] != a[5] or b[1] == b[3] or b[1] != b[5]:
        ans += "A"

    # 規則 B：首句末字為仄(1)，二句末字為平(0)
    if a[6] ??? 1 or b[6] ??? 0:
        ans += "B"

    # 規則 C：兩句二四六位置平仄必須不同 (對仗)
    if a[1] ??? b[1] or a[3] ??? b[3] or a[5] ??? b[5]:
        ans += "C"

    if ans == "":
        print("None")
    else:
        print(???)

# %% [markdown]
# ---
#
# ## **教師詳細導引過程 (100 分鐘流程)**
#
# ### **第一節 (50 分鐘)：IDLE 環境診斷與 Debug**
#
# 1. **環境體檢 (15')**：引導學生確認版本。解釋為什麼考場環境與平時習慣的 VS Code 不同（標準化與公平性）。
# 2. **IDLE 快捷鍵特訓 (15')**：
# * 練習 `F5` 快速執行。
# * 練習在 Shell 使用 `Alt + P` **快速叫回前一次輸入的複雜測資**，這在考場能節省大量手打時間。
# * 關閉 Shell : exit() or Ctrl-D (end-of-file) to exit
#
#
# 3. **閱讀報錯 (20')**：老師在 Editor 寫一段包含 `IndexError` 的程式碼，教導學生如何看 Shell 的紅字提示找到錯誤行號。
#
# ### **第二節 (50 分鐘)：限時解題模擬**
#
# 1. **限時衝刺 (30')**：挑戰 `g275` 或 `f605`。學生必須獨立在 IDLE 完成程式碼，並在自己的 Shell 視窗手動輸入測資驗證。
# 2. **考場策略分享 (10')**：
# * **「先求有，再求好」**：第一題拿滿分是報考 APCS 的首要目標。
# * **手寫邏輯**：引導學生在動手打字前，先在紙上寫下 `if` 的條件判斷式。
#
#
# 3. **成果截圖與反饋 (10')**：統計 AC 成功率，並確保每位學生都知道如何存檔帶走自己的程式碼。
#
# ---
#
# **💡 教師小筆記：**
# 這是系列課程的最終站。學生通常邏輯已具雛形，本週的關鍵在於 **「抗壓性」** 與 **「細心度」**。IDLE 雖然沒有自動提示，但能強迫學生精確記住 `range()`、`len()`、`split()` 等函式。提醒學生考場要 **「每 10 分鐘按一次 Ctrl+S」**，祝大家 APCS 順利奪得高分！

# %% [markdown]
# ---
# ## **學生檢查，檔案，資料夾**
# **💡 學生小筆記：**
# 這是系列課程的最終站。學生通常邏輯已具雛形，本週請檢察，關鍵**3個檔案**！

# %% [markdown]
# ![image.png](data:image/png;base64,...)
